# %% [markdown]
# <a href="https://colab.research.google.com/github/saverivakkalanka/AIML_LABS/blob/main/1st%20lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extracting features from data
#
# Module 1, Lab 1<br>

# %%
! pip install wikipedia

import wikipedia
import nltk
from nltk.util import ngrams
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import re
import unicodedata
import plotly.express as px
import pandas as pd

# %% [markdown]
# # Part 1: Features of text
# How do we apply machine learning on text? We can't directly use the text as input to our algorithms. We need to convert them to features. In this notebook, we will explore a simple way of converting text to features.
#
# Let us download a few documents off Wikipedia.

# %%
topic1 = 'Giraffe'
topic2 = 'Elephant'

fr_topic1 = 'Girafe'
fr_topic2 = 'Éléphant'

wikipedia.set_lang('en')

eng1 = wikipedia.page(topic1).content
eng2 = wikipedia.page(topic2).content

wikipedia.set_lang('fr')

fr1 = wikipedia.page(fr_topic1).content
fr2 = wikipedia.page(fr_topic2).content

# %% [markdown]
# ### Introduction to Feature Extraction
#
# This notebook demonstrates a fundamental concept in machine learning: **Feature Extraction**. Imagine you have a lot of raw data, like a long piece of text or an image. Computers don't understand this raw data directly. We need to convert it into a numerical format that a computer can process and learn from. These numerical representations are called **features**.
#
# This notebook explores two main areas:
#
# 1.  **Extracting Features from Text**: How do we turn words and characters into numbers?
# 2.  **Extracting Features from Images**: How do we get meaningful numbers from pictures of handwritten digits?
#
# Let's start by understanding the setup.

# %% [markdown]
# ### Part 0: Setting Up Our Environment (Cell OimBnfcpvcNS)
#
# Before we start, we need to import some tools (libraries) that help us do specific tasks. Think of these as adding special functions to our Python toolbox.
#
# *   `wikipedia`: To easily fetch content from Wikipedia.
# *   `nltk`: A powerful library for working with human language data (like text).
# *   `collections.Counter`: Helps us count things, like how many times a character appears.
# *   `matplotlib.pyplot` and `numpy`: For creating plots and working with numerical data.
# *   `re`: For working with regular expressions, which are patterns to find and manipulate text.
# *   `unicodedata`: For handling different text characters.
# *   `plotly.express` and `pandas`: For more advanced plotting and working with structured data.
#
# ```python
# ! pip install wikipedia
#
# import wikipedia
# import nltk
# from nltk.util import ngrams
# from collections import Counter
# import matplotlib.pyplot as plt
# import numpy as np
# import re
# import unicodedata
# import plotly.express as px
# import pandas as pd
# ```

# %% [markdown]
# ### Part 1: Features of Text
#
# Our first task is to extract features from text. The goal here is to see if we can create numerical features that allow us to distinguish between different languages (English vs. French) or different topics (Giraffe vs. Elephant).
#
# **1. Getting Text from Wikipedia (Cell lpUmCoEr2R3J)**
#
# We download Wikipedia pages for 'Giraffe' and 'Elephant' in both English and French. We store the content of these pages in variables like `eng1`, `eng2`, `fr1`, `fr2`.
#
# ```python
# topic1 = 'Giraffe'
# topic2 = 'Elephant'
#
# fr_topic1 = 'Girafe'
# fr_topic2 = 'Éléphant'
#
# wikipedia.set_lang('en')
#
# eng1 = wikipedia.page(topic1).content
# eng2 = wikipedia.page(topic2).content
#
# wikipedia.set_lang('fr')
#
# fr1 = wikipedia.page(fr_topic1).content
# fr2 = wikipedia.page(fr_topic2).content
# ```

# %% [markdown]
# **2. Cleaning the Text (Cells Cj7RlhMiO5kd, EZkmNJ7XO9xX, e5yf5P9pPI4t, qrOjC32fRuTK, rIdqvL2G-LqL)**
#
# The raw text from Wikipedia contains special characters, numbers, and uppercase letters that might interfere with our analysis. We define a `cleanup` function to make the text consistent:
#
# *   It converts all text to lowercase (`text.lower()`).
# *   It removes anything that isn't a lowercase letter (`re.sub('[^a-z]+', '', text)`). This simplifies the text significantly, but also means we lose accents and numbers.
#
# Then, we apply this function to all our downloaded texts.
#
# ```python
# def cleanup(text):
#   text = text.lower()  # make it lowercase
#   text = re.sub('[^a-z]+', '', text) # only keep characters
#   return text
#
# eng1 = cleanup(eng1)
# eng2 = cleanup(eng2)
# fr1 = cleanup(fr1)
# fr2 = cleanup(fr2)
#
# print(eng1)
# ```

# %% [markdown]
# **3. N-grams: Counting Character Sequences (Cells jXFTWwd0rk63, g3Lz3YUjN0L5)**
#
# An **N-gram** is a sequence of 'n' items from a given sample of text. Here, we are looking at character n-grams:
#
# *   **Unigram (n=1)**: A single character (e.g., 'a', 'b', 'c').
# *   **Bigram (n=2)**: A sequence of two characters (e.g., 'th', 'en', 'gr').
#
# The idea is that the frequency of these character sequences might be unique to a language or topic.
#
# We have helper functions to process these n-grams for plotting:
# *   `tuple2string`: Converts a tuple of characters (like `('a', 'b')`) into a string (`'ab'`).
# *   `key2string`: Applies `tuple2string` to a list of keys.
# *   `plothistogram`: Takes a dictionary of n-gram counts and displays them as a bar chart.
#
# ```python
# # convert a tuple of characters to a string
# def tuple2string(tup):
#   st = ''
#   for ii in tup:
#     st = st + ii
#   return st
#
# # convert a tuple of tuples to a list of strings
# def key2string(keys):
#   return [tuple2string(i) for i in keys]
#
# # plot the histogram
# def plothistogram(ngram):
#   keys = key2string(ngram.keys())
#   values = list(ngram.values())
#
#   # sort the keys in alphabetic order
#   combined = zip(keys, values)
#   zipped_sorted = sorted(combined, key=lambda x: x[0])
#   keys, values = map(list, zip(*zipped_sorted))
#   plt.bar(keys, values)
# ```

# %% [markdown]
# **4. Analyzing Unigrams (Cells zHD62zbZcwAB, LKcGRgH6b0KP, fDM_UhCL2QLt, kxgrdZLKdkAB)**
#
# We first calculate and plot the frequency of single characters (unigrams) for our English and French texts. `Counter(ngrams(text, 1))` does the counting.
#
# ```python
# unigram_eng1 = Counter(ngrams(eng1,1))
# plothistogram(unigram_eng1)
# plt.title('English 1')
# plt.show()
# unigram_eng2 = Counter(ngrams(eng2,1))
# plothistogram(unigram_eng2)
# plt.title('English 2')
# plt.show()
#
# unigram_fr1 = Counter(ngrams(fr1,1))
# plothistogram(unigram_fr1)
# plt.title('French 1')
# plt.show()
# unigram_fr2 = Counter(ngrams(fr2,1))
# plothistogram(unigram_fr2)
# plt.title('French 2')
# plt.show()
# ```
#
# **Observation**: You'll notice that the unigram distributions (how often each letter appears) are quite similar across English and French. This suggests that single character frequencies aren't a strong feature for distinguishing between these two languages.

# %% [markdown]
# **5. Analyzing Bigrams (Cells OmRCxItx2T9W, O-egsHMIg5Rp, 3EaPJgtaVxZM, M7jq3AwnVzQT, UXPTOj67WsPT, rGOEHcyGokD0, dk2TkzTno8vb, _HeWNh_q0QZ1, 6kDovOP4l98z)**
#
# Next, we move to **bigrams** (sequences of two characters). We expect these to be more distinctive.
#
# We plot histograms for bigrams, similar to unigrams:
#
# ```python
# bigram_eng1 = Counter(ngrams(eng1,2)) # bigrams
# plothistogram(bigram_eng1)
# plt.title('English 1')
# plt.show()
#
# bigram_eng2 = Counter(ngrams(eng2,2))
# plothistogram(bigram_eng2)
# plt.title('English 2')
# plt.show()
#
# bigram_fr1 = Counter(ngrams(fr1,2))
# plothistogram(bigram_fr1)
# plt.title('French 1')
# plt.show()
#
# bigram_fr2 = Counter(ngrams(fr2,2))
# plothistogram(bigram_fr2)
# plt.title('French 2')
# plt.show()
# ```
#
# We also visualize bigrams using a 2D heatmap. Each axis represents a character, and the color intensity shows the frequency of that character pair. `plotbihistogram` creates this 2D frequency matrix.
#
# ```python
# def plotbihistogram(ngram):
#   freq = np.zeros((26,26))
#   for ii in range(26):
#     for jj in range(26):
#       freq[ii,jj] = ngram[(chr(ord('a')+ii), chr(ord('a')+jj))]
#   plt.imshow(freq, cmap = 'jet')
#   return freq
#
# bieng1 = plotbihistogram(bigram_eng1)
# plt.show()
# bieng2 = plotbihistogram(bigram_eng2)
# plt.show()
#
# bifr1 = plotbihistogram(bigram_fr1)
# plt.show()
# bifr2 = plotbihistogram(bigram_fr2)
# plt.show()
# ```
#
# Finally, we have `ShowTopN` to list the most frequent bigrams. This helps us see the dominant character pairs.
#
# ```python
# def ind2tup(ind):
#   ind = int(ind/26)
#   j = int(ind%26)
#   return (chr(ord('a')+i), chr(ord('a')+j))
#
# def ShowTopN(bifreq, n=10):
#   f = bifreq.flatten()
#   arg = np.argsort(-f)
#   for ii in range(n):
#     print(f'{ind2tup(arg[ii])} : {f[arg[ii]]}')
#
# print('\nEnglish 1:')
# ShowTopN(bieng1)
# print('\nEnglish 2:')
# ShowTopN(bieng2)
# print('\nFrench 1:')
# ShowTopN(bifr1)
# print('\nFrench 2:')
# ShowTopN(bifr2)
# ```
#
# **Observation**: The bigram frequencies are more distinct between English and French. For example, common English bigrams like 'th' might be less frequent in French, and vice-versa. However, bigrams for 'Giraffe' and 'Elephant' within the *same language* are quite similar. This means bigrams are good for distinguishing languages, but not necessarily topics within the same language.

# %% [markdown]
# ### Part 2: Features of Written Numbers
#
# Now, let's switch gears to images. We'll use a famous dataset called **MNIST**, which contains images of handwritten digits (0-9). Our goal is to extract features that help us tell the difference between a handwritten '0' and a handwritten '1'. Each image is a small grid of 28x28 pixels.
#
# **1. Loading the Dataset (Cells yNsLJSr6wGY0, P3MN8ddxAASZ, BQeyZSh-Arpc)**
#
# We load the MNIST dataset and then pick out only the images of '0's and '1's for our experiment. We also visualize a few of them to see what they look like.
#
# ```python
# from keras.datasets import mnist
#
# #loading the dataset
# (train_X, train_y), (test_X, test_y) = mnist.load_data()
#
# no1 = train_X[train_y==1,:,:]
# no0 = train_X[train_y==0,:,:]
#
# for ii in range(5):
#   plt.subplot(1, 5, ii+1)
#   plt.imshow(no1[ii,:,:])
# plt.show()
# for ii in range(5):
#   plt.subplot(1, 5, ii+1)
#   plt.imshow(no0[ii,:,:])
# plt.show()
# ```

# %% [markdown]
# **2. Feature 1: Sum of Pixels (Cells 1g-Tg7EKDz96, I8SztDk7CyZc, 8oW3XCOCE7Zv, i8PIe8o_DPpU)**
#
# A very simple feature is to just count how many pixels are 'on' (i.e., not completely black) in each digit's image. We sum up all the pixels that have a value greater than 0.
#
# ```python
# sum1 = np.sum(no1>0, (1,2)) # threshold before adding up
# sum0 = np.sum(no0>0, (1,2))
#
# plt.hist(sum1, alpha=0.7);
# plt.hist(sum0, alpha=0.7);
# plt.show()
# ```
#
# **Observation**: The histograms show that '1's generally have fewer active pixels than '0's (since '1' is a simpler shape). This feature already helps distinguish them quite well.

# %% [markdown]
# **3. Feature 2: Hole Pixels (Cells 7_hToEepFtl2, HwEnlm6RFFej, iw3HjgnupUEI, H0sjr23NYEFe, vS-4erNXtxMi, Dpm1dRgsety8)**
#
# This is a more complex feature. We try to count the number of 'hole pixels'. A hole pixel is a black pixel that is completely surrounded by non-black (digit) pixels. Think of the inside of a '0' or '8'.
#
# The `cumArray` function helps build up a cumulative sum of pixels, which is used by `getHolePixels` to identify these enclosed black areas. We visualize how this works for a sample image.
#
# ```python
# def cumArray(img):
#   img2 = img.copy()
#   for ii in range(1, img2.shape[1]):
#     img2[ii,:] = img2[ii,:] + img2[ii-1,:]  # for every row, add up all the rows above it.
#   img2 = img2>0
#   return img2
#
# def getHolePixels(img):
#   im1 = cumArray(img)
#   im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
#   im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
#   im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
#   hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
#   hole = hull & ~ (img>0) # remove the original digit to leave behind the holes
#   return hole
#
# imgs = [no1[456,:,:],  no0[456,:,:]]
# for img in imgs:
#   plt.subplot(1,2,1)
#   plt.imshow(getHolePixels(img))
#   plt.subplot(1,2,2)
#   plt.imshow(img)
#   plt.show()
#
# hole1 = np.array([getHolePixels(i).sum() for i in no1])
# hole0 = np.array([getHolePixels(i).sum() for i in no0])
#
# plt.hist(hole1, alpha=0.7);
# plt.hist(hole0, alpha=0.7);
# plt.show()
# ```
#
# **Observation**: '0's have significant hole pixels, while '1's typically have none. This feature is very effective at separating '0's from '1's.

# %% [markdown]
# **4. Feature 3: Hull Pixels (Cells 8UjCBHpJ31yq, vPtJ8eqolAOf, W3fOgyYjmJ48, M5rHal_HRWnE, WTLzYZLTRQ_p)**
#
# 'Hull pixels' refer to the total number of pixels if you were to 'fill in' all the holes in the digit. It's essentially the total area covered by the digit, including any internal holes. The `getHullPixels` function builds upon `cumArray` to achieve this.
#
# ```python
# def getHullPixels(img):
#   im1 = cumArray(img)
#   im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
#   im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
#   im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
#   hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
#   return hull
#
# imgs = [no1[456,:,:],  no0[456,:,:]]
# for img in imgs:
#   plt.subplot(1,2,1)
#   plt.imshow(getHullPixels(img))
#   plt.subplot(1,2,2)
#   plt.imshow(img)
#   plt.show()
#
# hull1 = np.array([getHullPixels(i).sum() for i in no1])
# hull0 = np.array([getHullPixels(i).sum() for i in no0])
#
# plt.hist(hull1, alpha=0.7);
# plt.hist(hull0, alpha=0.7);
# plt.show()
# ```
#
# **Observation**: Similar to sum of pixels, but potentially offering a slightly different perspective. '0's tend to have a larger hull area than '1's.

# %% [markdown]
# **5. Feature 4: Boundary Pixels (Cells OSzH26ElXNri, h-2czBypXMwT, u-V688jFerXh, kSsxsbCNXcNh)**
#
# This feature counts the number of pixels that lie on the *edge* of the digit. A pixel is a boundary pixel if it's 'on' but at least one of its neighbors (up, down, left, right) is 'off'. The `getBoundaryPixels` function checks for this by shifting the image and comparing.
#
# ```python
# def minus(a, b):
#   return a & ~ b
#
# def getBoundaryPixels(img):
#   img = img.copy()>0  # binarize the image
#   rshift = np.roll(img, 1, 1)
#   lshift = np.roll(img, -1 ,1)
#   ushift = np.roll(img, -1, 0)
#   dshift = np.roll(img, 1, 0)
#   boundary = minus(img, rshift) | minus(img, lshift) | minus(img, ushift) | minus(img, dshift)
#   return boundary
#
# imgs = [no1[456,:,:],  no0[456,:,:]]
# for img in imgs:
#   plt.subplot(1,2,1)
#   plt.imshow(getBoundaryPixels(img))
#   plt.subplot(1,2,2)
#   plt.imshow(img)
#   plt.show()
#
# bound1 = np.array([getBoundaryPixels(i).sum() for i in no1])
# bound0= np.array([getBoundaryPixels(i).sum() for i in no0])
#
# plt.hist(bound1, alpha=0.7);
# plt.hist(bound0, alpha=0.7);
# plt.show()
# ```
#
# **Observation**: '0's, being rounder shapes, might have more boundary pixels than '1's, which are generally straighter.

# %% [markdown]
# **6. Combining Features (Cells WuP04Ao_R0Yz, kl7xWg-WRkAy, 0JYLmKNFSIT-, lOKEHIXFaWp_)**
#
# While individual features are helpful, combining them often provides even better separation between classes. We can visualize two features at a time using 2D scatter plots, and three features using 3D scatter plots.
#
# *   **2D Scatter Plots**: We plot pairs of features (Sum vs. Hull, Sum vs. Hole, Boundary vs. Hole) and color-code them by digit (0 or 1). This shows if the features create distinct clusters for each digit.
#
# ```python
# # Sum and hull
# plt.scatter(sum0, hull0, alpha=0.1)
# plt.scatter(sum1, hull1, alpha=0.1)
# plt.xlabel('Sum')
# plt.ylabel('Hull')
# plt.legend(['0','1'])
# plt.show()
#
# # Sum and hole
# plt.scatter(sum0, hole0, alpha=0.1)
# plt.scatter(sum1, hole1, alpha=0.1)
# plt.xlabel('Sum');
# plt.ylabel('Hole');
# plt.legend(['0','1'])
# plt.show()
#
# # Hole and boundary
# plt.scatter(bound0, hole0, alpha=0.1)
# plt.scatter(bound1, hole1, alpha=0.1)
# plt.xlabel('Boundary');
# plt.ylabel('Hole');
# plt.legend(['0','1'])
# plt.show()
# ```
#
# *   **3D Scatter Plot**: For three features, we use a 3D plot from `plotly.express`. This allows you to interactively rotate and zoom to see the separation in a three-dimensional space. We combine the features into a Pandas DataFrame first for easier plotting.
#
# ```python
# cl1 = ['class 1']*len(sum1)
# cl0 = ['class 0']*len(sum0)
# df = pd.DataFrame(list(zip(np.concatenate((hole1, hole0)), np.concatenate((sum1,sum0)),
#                            np.concatenate((bound1,bound0)), np.concatenate((cl1, cl0)))),
#                columns =['Hole', 'Sum', 'Boundary', 'Class'])
# df.head()
# fig = px.scatter_3d(df, x='Hole', y='Sum', z='Boundary', color='Class', opacity=0.1)
# fig.show()
# ```
#
# **Key Takeaway**: By combining multiple features, we can often achieve a much clearer separation between different categories (like digits '0' and '1') than with just one feature alone. This makes it easier for a machine learning model to classify them.

# %% [markdown]
# ### Conclusion and Further Exploration
#
# This notebook showed how we can convert raw, complex data (text and images) into simpler, numerical **features**. These features can then be used by machine learning algorithms to perform tasks like language identification or digit classification.
#
# **To summarize:**
#
# *   **Text Features**: Unigrams were not great for language distinction, but **bigrams** proved effective for distinguishing between English and French.
# *   **Image Features**: Simple features like the **sum of pixels**, and more complex ones like **hole pixels**, **hull pixels**, and **boundary pixels**, were all useful in separating handwritten '0's from '1's. Combining these features provided even better separation.
#
# **Questions to Ponder (for further learning):**
#
# 1.  **Which is the best combination of features?** This would involve trying out different pairs or groups of features and seeing which ones create the clearest separation. You might use statistical measures to quantify this.
# 2.  **How would you test or visualize four or more features?** Visualizing beyond 3D becomes tricky. Techniques like dimensionality reduction (e.g., PCA, t-SNE) can project higher-dimensional data into 2D or 3D for visualization, or you might rely on classification accuracy metrics.
# 3.  **Can you come up with your own features?** Absolutely! For images, you could think about aspect ratio, number of horizontal/vertical lines, symmetry, etc. For text, trigrams (3-character sequences), word counts, or sentiment scores could be features.
# 4.  **Will these features work for different classes other than 0 and 1?** Some might, some might not. For example, 'hole pixels' would be great for distinguishing '8's (two holes) from '3's (no holes), but less useful for '7's vs. '1's.
# 5.  **What will happen if we take more than two classes at a time?** The challenge increases. Features that separate '0' from '1' might not effectively separate '0' from '7', or '1' from '4'. You'd need features that can distinguish all the classes simultaneously.

# %% [markdown]
# This is what the text looks like:

# %%
fr2

# %% [markdown]
# We need to clean this up a bit. Let us remove all the special characters and keep only 26 letters and space. Note that this will remove accented characters in French also. We are also removing all the numbers and spaces. So this is not an ideal solution.

# %%
def cleanup(text):
  text = text.lower()  # make it lowercase
  text = re.sub('[^a-z]+', '', text) # only keep characters
  return text

# %%
eng1 = cleanup(eng1)
eng2 = cleanup(eng2)
fr1 = cleanup(fr1)
fr2 = cleanup(fr2)

# %%
print(eng1)

# %% [markdown]
# Now let us calculate the frequency of the character n-grams. N-grams are groups of characters of size n. A unigram is a single character and a bigram is a group of two characters and so on.
#
# Let us count the frequency of each character in a text and plot it in a histogram.

# %%
# convert a tuple of characters to a string
def tuple2string(tup):
  st = ''
  for ii in tup:
    st = st + ii
  return st

# convert a tuple of tuples to a list of strings
def key2string(keys):
  return [tuple2string(i) for i in keys]

# plot the histogram
def plothistogram(ngram):
  keys = key2string(ngram.keys())
  values = list(ngram.values())

  # sort the keys in alphabetic order
  combined = zip(keys, values)
  zipped_sorted = sorted(combined, key=lambda x: x[0])
  keys, values = map(list, zip(*zipped_sorted))
  plt.bar(keys, values)

# %% [markdown]
# Let us compare the histograms of English pages and French pages. Can you spot a difference?

# %%
unigram_eng1 = Counter(ngrams(eng1,1))
plothistogram(unigram_eng1)
plt.title('English 1')
plt.show()
unigram_eng2 = Counter(ngrams(eng2,1))
plothistogram(unigram_eng2)
plt.title('English 2')
plt.show()

# %%
unigram_fr1 = Counter(ngrams(fr1,1))
plothistogram(unigram_eng1)
plt.title('French 1')
plt.show()
unigram_fr2 = Counter(ngrams(fr2,1))
plothistogram(unigram_fr2)
plt.title('French 2')
plt.show()

# %% [markdown]
# We can see that the unigrams for French and English are very similar. So this is not a good feature if we want to distinguish between English and French. Let us look at bigrams.

# %%
bigram_eng1 = Counter(ngrams(eng1,2)) # bigrams
plothistogram(bigram_eng1)
plt.title('English 1')
plt.show()

bigram_eng2 = Counter(ngrams(eng2,2))
plothistogram(bigram_eng2)
plt.title('English 2')
plt.show()

bigram_fr1 = Counter(ngrams(fr1,2))
plothistogram(bigram_eng1)
plt.title('French 1')
plt.show()

bigram_fr2 = Counter(ngrams(fr2,2))
plothistogram(bigram_fr2)
plt.title('French 2')
plt.show()

# %% [markdown]
# Another way to visualize bigrams is to use a 2-dimensional graph.

# %%
def plotbihistogram(ngram):
  freq = np.zeros((26,26))
  for ii in range(26):
    for jj in range(26):
      freq[ii,jj] = ngram[(chr(ord('a')+ii), chr(ord('a')+jj))]
  plt.imshow(freq, cmap = 'jet')
  return freq

# %%
bieng1 = plotbihistogram(bigram_eng1)
plt.show()
bieng2 = plotbihistogram(bigram_eng2)

# %%
bifr1 = plotbihistogram(bigram_fr1)
plt.show()
bifr2 = plotbihistogram(bigram_fr2)

# %% [markdown]
# Let us look at the top 10 ngrams for each text.

# %%
from IPython.core.debugger import set_trace

def ind2tup(ind):
  ind = int(ind)
  i = int(ind/26)
  j = int(ind%26)
  return (chr(ord('a')+i), chr(ord('a')+j))

def ShowTopN(bifreq, n=10):
  f = bifreq.flatten()
  arg = np.argsort(-f)
  for ii in range(n):
    print(f'{ind2tup(arg[ii])} : {f[arg[ii]]}')

# %%
print('\nEnglish 1:')
ShowTopN(bieng1)
print('\nEnglish 2:')
ShowTopN(bieng2)
print('\nFrench 1:')
ShowTopN(bifr1)
print('\nFrench 2:')
ShowTopN(bifr2)

# %% [markdown]
# We observe that the bigrams are similar across different topics but different across languages. Thus, the bigram frequency is a good feature for distinguishing languages, but not for distinguishing topics.
#
# Thus, we were able to convert a many-dimensional input (the text) to 26 dimesions (unigrams) or 26*26 dimensions (bigrams).
#
#
# A few ways to explore:
# 1. Try with different languages.
# 2. The topics we used are quite similar, wikipedia articles of 'elephant' and 'giraffe'. What happens if we use very different topics? What if we use text from another source than Wikipedia?
# 3. How can we use and visualize trigrams and higher n-grams?

# %% [markdown]
# # Part 2: Written numbers
#
# We will use a subset of the MNIST dataset. Each input character is represented in a 28*28 array. Let us see if we can extract some simple features from these images which can help us distinguish between the digits.
#
# Load the dataset:

# %%
from keras.datasets import mnist

#loading the dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %% [markdown]
# Extract a subset of the data for our experiment:

# %%
no1 = train_X[train_y==1,:,:]
no0 = train_X[train_y==0,:,:]

# %% [markdown]
# Let us visualize a few images here:

# %%
for ii in range(5):
  plt.subplot(1, 5, ii+1)
  plt.imshow(no1[ii,:,:])
plt.show()
for ii in range(5):
  plt.subplot(1, 5, ii+1)
  plt.imshow(no0[ii,:,:])
plt.show()

# %% [markdown]
# suNow, let us start with a simple feature: the sum of all pixels and see how good this feature is.

# %%
sum1 = np.sum(no1>0, (1,2)) # threshold before adding up
sum0 = np.sum(no0>0, (1,2))

# %% [markdown]
# Let us visualize how good this feature is: (X-axis is mean, y-axis is the digit)

# %%
plt.hist(sum1, alpha=0.7);
plt.hist(sum0, alpha=0.7);

# %% [markdown]
# We can already see that this feature separates the two classes quite well.
#
# Let us look at another, more complicated feature. We will count the number black pixels that are surrounded on four sides by non-black pixels, or "hole pixels".

# %%
def cumArray(img):
  img2 = img.copy()
  for ii in range(1, img2.shape[1]):
    img2[ii,:] = img2[ii,:] + img2[ii-1,:]  # for every row, add up all the rows above it.
  img2 = img2>0
  return img2

def getHolePixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  hole = hull & ~ (img>0) # remove the original digit to leave behind the holes
  return hole

# %% [markdown]
# Visualize a few:

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getHolePixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %% [markdown]
# Now let us plot the number of hole pixels and see how this feature behaves

# %%
hole1 = np.array([getHolePixels(i).sum() for i in no1])
hole0 = np.array([getHolePixels(i).sum() for i in no0])

plt.hist(hole1, alpha=0.7);
plt.hist(hole0, alpha=0.7);

# %% [markdown]
# This feature works even better to distinguish between one and zero.
#
#
# Now let us try the number of pixels in the 'hull' or the number with the holes filled in:

# %%
def getHullPixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  return hull

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getHullPixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %% [markdown]
# Plotting the number of hull pixels versus the digit:

# %%
hull1 = np.array([getHullPixels(i).sum() for i in no1])
hull0 = np.array([getHullPixels(i).sum() for i in no0])

plt.hist(hull1, alpha=0.7);
plt.hist(hull0, alpha=0.7);

# %% [markdown]
# Let us try one more feature, where we look at the number of boundary pixels in each image.

# %%
def minus(a, b):
  return a & ~ b

def getBoundaryPixels(img):
  img = img.copy()>0  # binarize the image
  rshift = np.roll(img, 1, 1)
  lshift = np.roll(img, -1 ,1)
  ushift = np.roll(img, -1, 0)
  dshift = np.roll(img, 1, 0)
  boundary = minus(img, rshift) | minus(img, lshift) | minus(img, ushift) | minus(img, dshift)
  return boundary

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getBoundaryPixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %%
bound1 = np.array([getBoundaryPixels(i).sum() for i in no1])
bound0= np.array([getBoundaryPixels(i).sum() for i in no0])

plt.hist(bound1, alpha=0.7);
plt.hist(bound0, alpha=0.7);

# %% [markdown]
# What will happen if we plot two features together?

# %%
# Sum and hull
plt.scatter(sum0, hull0, alpha=0.1)
plt.scatter(sum1, hull1, alpha=0.1)
plt.xlabel('Sum')
plt.ylabel('Hull')
plt.legend(['0','1'])
plt.show()

# Sum and hole
plt.scatter(sum0, hole0, alpha=0.1)
plt.scatter(sum1, hole1, alpha=0.1)
plt.xlabel('Sum');
plt.ylabel('Hole');
plt.legend(['0','1'])
plt.show()

# Hole and boundary
plt.scatter(bound0, hole0, alpha=0.1)
plt.scatter(bound1, hole1, alpha=0.1)
plt.xlabel('Boundary');
plt.ylabel('Hole');
plt.legend(['0','1'])
plt.show()

# %% [markdown]
# Now let us try plotting 3 features together.

# %%
cl1 = ['class 1']*len(sum1)
cl0 = ['class 0']*len(sum0)
df = pd.DataFrame(list(zip(np.concatenate((hole0, hole0)), np.concatenate((sum1,sum0)),
                           np.concatenate((bound1,bound0)), np.concatenate((cl1, cl0)))),
               columns =['Hole', 'Sum', 'Boundary', 'Class'])
df.head()
fig = px.scatter_3d(df, x='Hole', y='Sum', z='Boundary', color='Class', opacity=0.1)
fig.show()

# %% [markdown]
# Feel free to explore the above graph with your mouse.
#
#
# We have seen that we extracted four features from a 28*28 dimensional image.
#
#
# Some questions to explore:
# 1. Which is the best combination of features?
# 2. How would you test or visualize four or more features?
# 3. Can you come up with your own features?
# 4. Will these features work for different classes other than 0 and 1?
# 5. What will happen if we take more that two classes at a time?
